# %% [markdown]
# # Digital Image Processing

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = plt.imread('C:\\Users\\Dell\\Documents\\JupyterNotebook\\Scientific Python Ecosystem\\images\\pic1.png')
img2 = plt.imread('C:\\Users\\Dell\\Documents\\JupyterNotebook\\Scientific Python Ecosystem\\images\\wall6.png')

# %%
print(img1)
# Out:
# [[[0.44313726 0.6039216  0.7137255  1.        ]
#   [0.44313726 0.6039216  0.7137255  1.        ]
#   [0.44313726 0.6039216  0.7137255  1.        ]
#   ...
#   [0.3647059  0.5764706  0.7058824  1.        ]
#   [0.3529412  0.5764706  0.7019608  1.        ]
#   [0.3372549  0.56078434 0.69411767 1.        ]]
#
#  [[0.44705883 0.6039216  0.7058824  1.        ]
#   [0.4509804  0.60784316 0.7137255  1.        ]
#   [0.4509804  0.6039216  0.7137255  1.        ]
#   ...
#   [0.36078432 0.5803922  0.7058824  1.        ]
#   [0.34509805 0.5686275  0.69411767 1.        ]
#   [0.33333334 0.5647059  0.69411767 1.        ]]
#
#  [[0.45490196 0.6039216  0.7058824  1.        ]
#   [0.4509804  0.6039216  0.7058824  1.        ]
#   [0.45490196 0.60784316 0.70980394 1.        ]
#   ...
#   [0.3529412  0.57254905 0.69803923 1.        ]
#   [0.34901962 0.57254905 0.69411767 1.        ]
#   [0.3372549  0.5647059  0.69803923 1.        ]]
#
#  ...
#
#  [[0.01960784 0.07058824 0.01568628 1.        ]
# ...

# %%
print("Array type :",type(img1))
print("Shape of image :",img1.shape)
print("Dimension of image :",img1.ndim)
print("size of image :",img1.size)
print("data type :",img1.dtype)
print("No. of bytes :",img1.nbytes)
# Out:
# Array type : <class 'numpy.ndarray'>
# Shape of image : (256, 256, 4)
# Dimension of image : 3
# size of image : 262144
# data type : float32
# No. of bytes : 1048576

# %%
print(img1[10,10,0]) #red intensity  
print(img1[10,10,1]) #blue intensity
print(img1[10,10,2]) #green intensity
# Out:
# 0.49411765
# 0.6392157
# 0.72156864

# %%
plt.imshow(img1)
