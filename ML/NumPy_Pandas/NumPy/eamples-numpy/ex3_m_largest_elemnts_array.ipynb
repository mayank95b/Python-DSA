# %% [markdown]
# #### get the n largest values of an array

# %%
import numpy as np

x = np.arange(1000)
np.random.shuffle(x)
n = 5
x # Shuffled array
# Out:
# array([276, 774, 645, 166, 177,  89,  25, 375, 898,  43, 888, 180, 871,
#        639, 583, 543, 336,  66,  37, 108, 628, 457, 189, 118, 194, 823,
#        786, 206, 709, 794, 476, 405, 974, 155, 577, 528, 430, 238, 653,
#        132, 604, 596, 250, 355, 133,  42, 902, 533, 947, 831, 412, 723,
#        747, 891, 658,  81, 618,   2, 973, 500, 744, 987, 145, 860, 193,
#        229, 997, 917, 408, 634, 110, 147, 546, 356, 214, 427, 721, 791,
#        980, 331, 607, 114, 770, 919, 750,  13, 198, 741, 288, 226, 547,
#        671, 314, 344, 922,  19, 397, 869, 248, 719, 531, 161, 939, 555,
#        436, 916, 378, 969, 558,  17, 241, 817, 393, 160, 664, 732, 305,
#         68, 646, 661,  10, 400,  18, 859, 513,   5, 348,  62, 627, 612,
#        797, 659, 854,  83, 895, 125, 972, 781, 437, 836,  56, 644, 320,
#         28, 175, 451, 318, 304, 910, 144, 967, 594, 921,  40, 303, 784,
#        201,  14, 643, 328, 601, 640,  50, 816, 109, 503, 549,  31, 727,
# ...

# %%
print(x[np.argsort(x)[-n:]])
# Out:
# [995 996 997 998 999]
